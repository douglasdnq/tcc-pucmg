# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar as bibliotecas necessárias: destaque para pytorch

import numpy as np
import PIL.Image

import torch, torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import time

from matplotlib import pyplot as plt

import os

# %%
from torchvision.transforms.functional import crop

def bottom_crop(image):
    return crop(image, 2*image_size/3, 2*image_size/3, image_size, image_size)

# %%
image_size = 100

# Transformação as imagens!
transformacoes_de_imagens = { 
    'treino': transforms.Compose([
        transforms.Resize(size=[image_size, image_size]),
        transforms.Lambda(bottom_crop),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'validacao': transforms.Compose([
        transforms.Resize(size=[image_size, image_size]),
        transforms.Lambda(bottom_crop),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'teste': transforms.Compose([
        transforms.Resize(size=[image_size, image_size]),
        transforms.Lambda(bottom_crop),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
# Carregar as imagens
# Determinar as pastas de treino, validação e teste

dataset = r'/content/drive/MyDrive/data'

pasta_treino = os.path.join(dataset, 'treino')
pasta_validacao = os.path.join(dataset, 'validacao')
pasta_teste = os.path.join(dataset, 'teste')

# %%
# Tamanho do batch de treinamento
bs = 16

# Determinando o número de classes
numero_de_classes = len(os.listdir(pasta_validacao))

# %%
numero_de_classes
# Out:
# 3

# %%
# Carregar as imagens usando o datasets do torchvision
data = {
    'treino': datasets.ImageFolder(root=pasta_treino, transform=transformacoes_de_imagens['treino']),
    'validacao': datasets.ImageFolder(root=pasta_validacao, transform=transformacoes_de_imagens['validacao'])
}

# %%
data
# Out:
# {'treino': Dataset ImageFolder
#      Number of datapoints: 105
#      Root location: /content/drive/MyDrive/data/treino
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=[100, 100], interpolation=bilinear, max_size=None, antialias=None)
#                 Lambda()
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             ), 'validacao': Dataset ImageFolder
#      Number of datapoints: 15
#      Root location: /content/drive/MyDrive/data/validacao
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=[100, 100], interpolation=bilinear, max_size=None, antialias=None)
#                 Lambda()
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             )}

# %%
# Mapear os índices com os nomes das classes (bayc, mayc e pap)
indice_para_classe = {v: k for k, v in data['treino'].class_to_idx.items()}
print(indice_para_classe)

# Quantidade de imagens para serem utilizados para calcular erro médio e acurácia
num_imagens_treino = len(data['treino'])
num_imagens_validacao = len(data['validacao'])

# Cria os DataLoaders para treino e validação
data_loader_treino = DataLoader(data['treino'], batch_size=bs, shuffle=True)
data_loader_validacao = DataLoader(data['validacao'], batch_size=bs, shuffle=True)
# Out:
# {0: 'bayc', 1: 'mayc', 2: 'pap'}

# %%
from IPython.display import Image 

# Mostrar algumas imagens
for classe in indice_para_classe.values():
    pasta_classe = os.path.join(pasta_treino, classe)
    arquivo_imagem = os.listdir(pasta_classe)[1]
    img = Image(filename=os.path.join(pasta_classe, arquivo_imagem))
    display(img)

# %%
alexnet = models.alexnet(pretrained=True)
alexnet
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Congelar os parametros da rede pré-treinada
for param in alexnet.parameters():
    param.requires_grad = False

# %%
# Mudar a última camada para alterar o número de classes
alexnet.classifier[6] = nn.Linear(4096, numero_de_classes)
alexnet.classifier.add_module("7", nn.LogSoftmax(dim = 1))
alexnet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
# Definição de algoritmo de otimização de gradiente descendente e função de erro
funcao_erro = nn.NLLLoss() # negative log likelihood loss
otimizador = optim.Adam(alexnet.parameters()) # otimizador de passos para o SGD
otimizador
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
def treinar_e_validar(modelo, metrica_erro, otimizador_sgd, epocas=25):
    '''
    Função para treinamento e validação
    Parâmetros
        :param modelo: modelo para treinar e validar
        :param metrica_erro: critério de erro para minização
        :param otimizador_sgd: otimizador para calcular os gradientes
        :param epocas: número de épocas 
    Retorna
        melhor_modelo: modelo treinado com a melhor acurácia na validação
        historico: (dicionário): histórico com erro no treinamento, erro na validação e acurácia
    '''
    
    # inicializando historico, a melhor acuracia de validação e o melhor modelo de acordo com a validação
    historico = []
    melhor_acuracia = 0.0
    melhor_modelo = None

    # Cada época perpassa todas as imagens do treino e calcula erros de treino e validação
    # para aprendizado da rede neural
    for epoca in range(epocas):
        inicio_epoca = time.time()
        print("\n\nÉpoca: {}/{}".format(epoca+1, epocas))
        
        # Mudar o modelo para modo treino: vai atualizar os parametros da rede neural
        modelo.train()
        
        # Erro e acurácia de treino nessa época
        erro_treino = 0.0
        acuracia_treino = 0.0
        
        # Erro e acurácia de validação nessa época
        erro_validacao = 0.0
        acuracia_validacao = 0.0
        
        # Itera a cada lote de imagem. As entradas são os tensores do lote (batch)
        # e o label são as classificações de cada imagem do lote: 
        # bayc, mayc ou pap (0, 1 e 2)
        for i, (entradas, labels) in enumerate(data_loader_treino):

            # joga pra GPU ou CPU, dependendo do seu hardware
            entradas = entradas.to(device)
            labels = labels.to(device)
            
            # Limpar os gradientes: zerar os gradientes
            otimizador_sgd.zero_grad()
            
            # Forward pass - calcular saídas a partir das entradas utilizando o modelo
            saidas = modelo(entradas)
            
            # Calcular erro das saidas que foram preditas no forward pass
            # comparando com as classificacoes reais (predito vs real)
            erro = metrica_erro(saidas, labels)
            
            # Realizar backpropagation do erro para treinar os coeficientes da rede
            erro.backward()
            
            # Atualizar os parâmetros do otimizador (no nosso caso, Adam Optimizer)
            otimizador_sgd.step()
            
            # Calcular o erro total para esse lote (batch) e soma o erro no treino
            erro_treino += erro.item() * entradas.size(0)
            
            # Cálculo da acurácia
            # Pra calcular a acurácia temos que buscar as classes preditas para cada imagem no lote
            
            # Cada tensor é uma imagem do lote com três posições: probabilidades de cada classe
            # torch.max vai retornar o valor da maior probabilidade, bem como a posição no tensor (tupla de saída)
            # A posição, portanto, vai indicar a classe com maior probabilidade (0,1 ou 2)
            # 1o busca o valor máximo de cada tensor de cada imagem, que vai dar 
            valores_maximos, indices_dos_valores_maximos = torch.max(saidas.data, 1)
            predicoes_corretas = indices_dos_valores_maximos.eq(labels.data.view_as(indices_dos_valores_maximos))
            
            # Converter os acertos para float e calcular a acurácia média
            acuracia = torch.mean(predicoes_corretas.type(torch.FloatTensor))
            
            # Calcular a acurácia total de treino do lote todo e adicionar a em train_acc
            acuracia_treino += acuracia.item() * entradas.size(0)
            
            print("Treino - Lote número {:03d}, Erro: {:.4f}, Acurácia: {:.4f}".format(i, erro.item(), acuracia.item()))

            
        # Validação - não é necessário rastrear os gradientes, pois o modelo não vai ser treinado com a validação
        with torch.no_grad():

            # Mudando de treino para validação
            modelo.eval()

            # Iteração de validação
            for j, (entradas, labels) in enumerate(data_loader_validacao):
                entradas = entradas.to(device)
                labels = labels.to(device)

                # Forward pass de validação
                saidas = modelo(entradas)

                # Calcular erro de validação
                erro = metrica_erro(saidas, labels)

                # Calcular erro de validação e adicionar a valid_loss
                erro_validacao += erro.item() * entradas.size(0)

                # Calcular a acurácia de validação
                valores_maximos, indices_dos_valores_maximos = torch.max(saidas.data, 1)
                predicoes_corretas = indices_dos_valores_maximos.eq(labels.data.view_as(indices_dos_valores_maximos))

                # Converter os acertos para float e calcular a acurácia média
                acuracia = torch.mean(predicoes_corretas.type(torch.FloatTensor))

                # Calcular a acurácia total de validação do lote todo e adicionar a em train_acc
                acuracia_validacao += acuracia.item() * entradas.size(0)

                print("Validação - Lote número: {:03d}, Erro: {:.4f}, Acurácia: {:.4f}".format(j, erro.item(), acuracia.item()))
            
        # Calcular a média de erro e acurácia no treino
        erro_medio_treino = erro_treino/num_imagens_treino
        acuracia_media_treino = acuracia_treino/num_imagens_treino

        # Calcular a média de erro e acurácia na validação
        erro_medio_validacao = erro_validacao/num_imagens_validacao
        acuracia_media_validacao = acuracia_validacao/num_imagens_validacao

        # Incluir no histórico os erros e acurácias médias
        historico.append([erro_medio_treino, erro_medio_validacao, acuracia_media_treino, acuracia_media_validacao])
                
        fim_epoca = time.time()
    
        print("Época : {:03d}, Treino: Erro: {:.4f}, Acurácia: {:.4f}%, \n\t\tValidação : Erro : {:.4f}, Acurácia: {:.4f}%, Tempo: {:.4f}s".format(epoca+1, erro_medio_treino, acuracia_media_treino*100, erro_medio_validacao, acuracia_media_validacao*100, fim_epoca-inicio_epoca))
        
        # Testa se a acurácia na validação desse modelo nessa época é a melhor
        # Se for a melhor, salva no melhor modelo e na melhor acurácia
        if acuracia_media_validacao > melhor_acuracia:
            melhor_acuracia = acuracia_media_validacao
            melhor_modelo = modelo
            torch.save(melhor_modelo, '/content/drive/MyDrive/modelos/melhor_modelo.pt')
          
    return melhor_modelo, historico

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define o número de épocas
numero_de_epocas = 50

# treina o modelo! Finalmente!!
modelo_treinado, historico = treinar_e_validar(alexnet, funcao_erro, otimizador, numero_de_epocas)
# Out:
# Época: 1/50
# Treino - Lote número 000, Erro: 0.0957, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.3014, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.2393, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.4172, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.2639, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.3289, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.2328, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3134, Acurácia: 0.8667
# Época : 001, Treino: Erro: 0.2708, Acurácia: 86.6667%,
# 		Validação : Erro : 0.3134, Acurácia: 86.6667%, Tempo: 2.6673s
#
#
# Época: 2/50
# Treino - Lote número 000, Erro: 0.0842, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.4582, Acurácia: 0.7500
# Treino - Lote número 002, Erro: 0.3365, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.2360, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.3342, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.1238, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.1245, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2955, Acurácia: 0.9333
# Época : 002, Treino: Erro: 0.2504, Acurácia: 90.4762%,
# 		Validação : Erro : 0.2955, Acurácia: 93.3333%, Tempo: 2.6589s
#
#
# Época: 3/50
# Treino - Lote número 000, Erro: 0.3536, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.0593, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.4980, Acurácia: 0.6875
# Treino - Lote número 003, Erro: 0.2080, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.3990, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.1044, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.4682, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.4181, Acurácia: 0.7333
# Época : 003, Treino: Erro: 0.2873, Acurácia: 85.7143%,
# 		Validação : Erro : 0.4181, Acurácia: 73.3333%, Tempo: 2.5744s
#
#
# Época: 4/50
# Treino - Lote número 000, Erro: 0.0231, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.4787, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.2152, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.3831, Acurácia: 0.7500
# Treino - Lote número 004, Erro: 0.0707, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.4055, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.3234, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.3001, Acurácia: 0.9333
# Época : 004, Treino: Erro: 0.2679, Acurácia: 87.6190%,
# 		Validação : Erro : 0.3001, Acurácia: 93.3333%, Tempo: 2.5735s
#
#
# Época: 5/50
# Treino - Lote número 000, Erro: 0.2495, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.1592, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.3553, Acurácia: 0.8125
# Treino - Lote número 003, Erro: 0.1850, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.2059, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.5429, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.1267, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3064, Acurácia: 0.8667
# Época : 005, Treino: Erro: 0.2696, Acurácia: 88.5714%,
# 		Validação : Erro : 0.3064, Acurácia: 86.6667%, Tempo: 2.9930s
#
#
# Época: 6/50
# Treino - Lote número 000, Erro: 0.3616, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.1045, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.0590, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.4070, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.1257, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.2642, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.0900, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3293, Acurácia: 0.8667
# Época : 006, Treino: Erro: 0.2092, Acurácia: 96.1905%,
# 		Validação : Erro : 0.3293, Acurácia: 86.6667%, Tempo: 2.7714s
#
#
# Época: 7/50
# Treino - Lote número 000, Erro: 0.0516, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.3485, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.2756, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.1548, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.2532, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.2995, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.2841, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2839, Acurácia: 0.9333
# Época : 007, Treino: Erro: 0.2351, Acurácia: 89.5238%,
# 		Validação : Erro : 0.2839, Acurácia: 93.3333%, Tempo: 2.6090s
#
#
# Época: 8/50
# Treino - Lote número 000, Erro: 0.5064, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.5417, Acurácia: 0.6875
# Treino - Lote número 002, Erro: 0.1668, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.2140, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.3103, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.1186, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.2542, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2849, Acurácia: 0.8667
# Época : 008, Treino: Erro: 0.3049, Acurácia: 85.7143%,
# 		Validação : Erro : 0.2849, Acurácia: 86.6667%, Tempo: 2.7098s
#
#
# Época: 9/50
# Treino - Lote número 000, Erro: 0.1694, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.1221, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.1020, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.2980, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.2760, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.4909, Acurácia: 0.7500
# Treino - Lote número 006, Erro: 0.2051, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2354, Acurácia: 0.9333
# Época : 009, Treino: Erro: 0.2398, Acurácia: 89.5238%,
# 		Validação : Erro : 0.2354, Acurácia: 93.3333%, Tempo: 2.6923s
#
#
# Época: 10/50
# Treino - Lote número 000, Erro: 0.2432, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.1322, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.2430, Acurácia: 0.8125
# Treino - Lote número 003, Erro: 0.3519, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.1909, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.3511, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.0990, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.1979, Acurácia: 0.8667
# Época : 010, Treino: Erro: 0.2389, Acurácia: 87.6190%,
# 		Validação : Erro : 0.1979, Acurácia: 86.6667%, Tempo: 2.6952s
#
#
# Época: 11/50
# Treino - Lote número 000, Erro: 0.0973, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.2963, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.4030, Acurácia: 0.7500
# Treino - Lote número 003, Erro: 0.1366, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.1895, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.1538, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.5748, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.1817, Acurácia: 0.9333
# Época : 011, Treino: Erro: 0.2438, Acurácia: 89.5238%,
# 		Validação : Erro : 0.1817, Acurácia: 93.3333%, Tempo: 2.6796s
#
#
# Época: 12/50
# Treino - Lote número 000, Erro: 0.3635, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.3434, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.2372, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.3896, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.3427, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.2389, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.3191, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.2083, Acurácia: 0.9333
# Época : 012, Treino: Erro: 0.3192, Acurácia: 84.7619%,
# 		Validação : Erro : 0.2083, Acurácia: 93.3333%, Tempo: 2.6494s
#
#
# Época: 13/50
# Treino - Lote número 000, Erro: 0.2303, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.1623, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.2287, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.6564, Acurácia: 0.7500
# Treino - Lote número 004, Erro: 0.4868, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.4660, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.2104, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2196, Acurácia: 0.9333
# Época : 013, Treino: Erro: 0.3579, Acurácia: 84.7619%,
# 		Validação : Erro : 0.2196, Acurácia: 93.3333%, Tempo: 2.5269s
#
#
# Época: 14/50
# Treino - Lote número 000, Erro: 0.1456, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.2304, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.3711, Acurácia: 0.8125
# Treino - Lote número 003, Erro: 0.2729, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.2440, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.0990, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.3203, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2629, Acurácia: 0.9333
# Época : 014, Treino: Erro: 0.2351, Acurácia: 89.5238%,
# 		Validação : Erro : 0.2629, Acurácia: 93.3333%, Tempo: 2.6582s
#
#
# Época: 15/50
# Treino - Lote número 000, Erro: 0.0847, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.0591, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.4033, Acurácia: 0.8125
# Treino - Lote número 003, Erro: 0.0900, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.1097, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.2880, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.0386, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2757, Acurácia: 0.8667
# Época : 015, Treino: Erro: 0.1610, Acurácia: 95.2381%,
# 		Validação : Erro : 0.2757, Acurácia: 86.6667%, Tempo: 2.7225s
#
#
# Época: 16/50
# Treino - Lote número 000, Erro: 0.1262, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.5824, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.4532, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.2215, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.5577, Acurácia: 0.7500
# Treino - Lote número 005, Erro: 0.1150, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.5812, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.4009, Acurácia: 0.9333
# Época : 016, Treino: Erro: 0.3631, Acurácia: 87.6190%,
# 		Validação : Erro : 0.4009, Acurácia: 93.3333%, Tempo: 2.6790s
#
#
# Época: 17/50
# Treino - Lote número 000, Erro: 0.1089, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.6685, Acurácia: 0.7500
# Treino - Lote número 002, Erro: 0.2134, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.3385, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.1008, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.3341, Acurácia: 0.6875
# Treino - Lote número 006, Erro: 0.0425, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3426, Acurácia: 0.8000
# Época : 017, Treino: Erro: 0.2725, Acurácia: 87.6190%,
# 		Validação : Erro : 0.3426, Acurácia: 80.0000%, Tempo: 2.6412s
#
#
# Época: 18/50
# Treino - Lote número 000, Erro: 0.3380, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.0735, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.5237, Acurácia: 0.8125
# Treino - Lote número 003, Erro: 0.0759, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.3849, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.1462, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.0192, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3092, Acurácia: 0.9333
# Época : 018, Treino: Erro: 0.2367, Acurácia: 91.4286%,
# 		Validação : Erro : 0.3092, Acurácia: 93.3333%, Tempo: 2.6395s
#
#
# Época: 19/50
# Treino - Lote número 000, Erro: 0.5492, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.4051, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.0353, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.1826, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.4694, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.1816, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.1313, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3008, Acurácia: 0.8667
# Época : 019, Treino: Erro: 0.2891, Acurácia: 92.3810%,
# 		Validação : Erro : 0.3008, Acurácia: 86.6667%, Tempo: 2.7066s
#
#
# Época: 20/50
# Treino - Lote número 000, Erro: 0.0510, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.1941, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.3664, Acurácia: 0.7500
# Treino - Lote número 003, Erro: 0.3531, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.1333, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.0226, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.5209, Acurácia: 0.5556
# Validação - Lote número: 000, Erro: 0.3038, Acurácia: 0.8667
# Época : 020, Treino: Erro: 0.2154, Acurácia: 87.6190%,
# 		Validação : Erro : 0.3038, Acurácia: 86.6667%, Tempo: 2.5599s
#
#
# Época: 21/50
# Treino - Lote número 000, Erro: 0.2233, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.2779, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.1209, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.2331, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.2830, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.2120, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.1697, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3070, Acurácia: 0.9333
# Época : 021, Treino: Erro: 0.2203, Acurácia: 88.5714%,
# 		Validação : Erro : 0.3070, Acurácia: 93.3333%, Tempo: 2.5949s
#
#
# Época: 22/50
# Treino - Lote número 000, Erro: 0.2285, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.0748, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.1481, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.0532, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.2182, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.0972, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.2525, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3275, Acurácia: 0.8667
# Época : 022, Treino: Erro: 0.1466, Acurácia: 93.3333%,
# 		Validação : Erro : 0.3275, Acurácia: 86.6667%, Tempo: 2.5827s
#
#
# Época: 23/50
# Treino - Lote número 000, Erro: 0.1884, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.1511, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.0672, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.2125, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.2012, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.1131, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.1328, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3333, Acurácia: 0.9333
# Época : 023, Treino: Erro: 0.1536, Acurácia: 92.3810%,
# 		Validação : Erro : 0.3333, Acurácia: 93.3333%, Tempo: 2.6189s
#
#
# Época: 24/50
# Treino - Lote número 000, Erro: 0.2442, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.4838, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.2148, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.2371, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.1335, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.1270, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.0516, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3570, Acurácia: 0.8667
# Época : 024, Treino: Erro: 0.2239, Acurácia: 91.4286%,
# 		Validação : Erro : 0.3570, Acurácia: 86.6667%, Tempo: 2.5542s
#
#
# Época: 25/50
# Treino - Lote número 000, Erro: 0.2824, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.1010, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.0960, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.3271, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.0684, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.2418, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.2082, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3643, Acurácia: 0.9333
# Época : 025, Treino: Erro: 0.1880, Acurácia: 92.3810%,
# 		Validação : Erro : 0.3643, Acurácia: 93.3333%, Tempo: 2.6169s
#
#
# Época: 26/50
# Treino - Lote número 000, Erro: 0.1794, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.3131, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.0549, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.3819, Acurácia: 0.7500
# Treino - Lote número 004, Erro: 0.1819, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.2000, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.0233, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3606, Acurácia: 0.9333
# Época : 026, Treino: Erro: 0.2018, Acurácia: 88.5714%,
# 		Validação : Erro : 0.3606, Acurácia: 93.3333%, Tempo: 2.6694s
#
#
# Época: 27/50
# Treino - Lote número 000, Erro: 0.3286, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.1811, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.0658, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.1327, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.4000, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.3627, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 1.0997, Acurácia: 0.5556
# Validação - Lote número: 000, Erro: 0.3543, Acurácia: 0.8667
# Época : 027, Treino: Erro: 0.3184, Acurácia: 88.5714%,
# 		Validação : Erro : 0.3543, Acurácia: 86.6667%, Tempo: 2.6089s
#
#
# Época: 28/50
# Treino - Lote número 000, Erro: 0.0288, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.1792, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.4518, Acurácia: 0.7500
# Treino - Lote número 003, Erro: 0.3646, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.6341, Acurácia: 0.6875
# Treino - Lote número 005, Erro: 0.4894, Acurácia: 0.7500
# Treino - Lote número 006, Erro: 0.3236, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3281, Acurácia: 0.9333
# Época : 028, Treino: Erro: 0.3550, Acurácia: 83.8095%,
# 		Validação : Erro : 0.3281, Acurácia: 93.3333%, Tempo: 2.5231s
#
#
# Época: 29/50
# Treino - Lote número 000, Erro: 0.1206, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.0500, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.1402, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.4032, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.3215, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.4082, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.1447, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3232, Acurácia: 0.8667
# Época : 029, Treino: Erro: 0.2324, Acurácia: 90.4762%,
# 		Validação : Erro : 0.3232, Acurácia: 86.6667%, Tempo: 2.6314s
#
#
# Época: 30/50
# Treino - Lote número 000, Erro: 0.5215, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.0357, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.1510, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.7441, Acurácia: 0.7500
# Treino - Lote número 004, Erro: 0.3107, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.4122, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.1708, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.3414, Acurácia: 0.9333
# Época : 030, Treino: Erro: 0.3461, Acurácia: 86.6667%,
# 		Validação : Erro : 0.3414, Acurácia: 93.3333%, Tempo: 2.5876s
#
#
# Época: 31/50
# Treino - Lote número 000, Erro: 0.1301, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.0439, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.1822, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.1252, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.2399, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.3475, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.3280, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2938, Acurácia: 0.8667
# Época : 031, Treino: Erro: 0.1910, Acurácia: 90.4762%,
# 		Validação : Erro : 0.2938, Acurácia: 86.6667%, Tempo: 2.6362s
#
#
# Época: 32/50
# Treino - Lote número 000, Erro: 0.1896, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.0460, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.0838, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.2901, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.1547, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.3487, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.2128, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2784, Acurácia: 0.8667
# Época : 032, Treino: Erro: 0.1878, Acurácia: 92.3810%,
# 		Validação : Erro : 0.2784, Acurácia: 86.6667%, Tempo: 2.6468s
#
#
# Época: 33/50
# Treino - Lote número 000, Erro: 0.2564, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.0782, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.8175, Acurácia: 0.6875
# Treino - Lote número 003, Erro: 0.0497, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.0383, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.0548, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.2243, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2795, Acurácia: 0.8667
# Época : 033, Treino: Erro: 0.2166, Acurácia: 92.3810%,
# 		Validação : Erro : 0.2795, Acurácia: 86.6667%, Tempo: 2.6303s
#
#
# Época: 34/50
# Treino - Lote número 000, Erro: 0.3625, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.3479, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.3531, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.0905, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.4595, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.0874, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.5456, Acurácia: 0.6667
# Validação - Lote número: 000, Erro: 0.3103, Acurácia: 0.8667
# Época : 034, Treino: Erro: 0.3060, Acurácia: 85.7143%,
# 		Validação : Erro : 0.3103, Acurácia: 86.6667%, Tempo: 2.5522s
#
#
# Época: 35/50
# Treino - Lote número 000, Erro: 0.4217, Acurácia: 0.6875
# Treino - Lote número 001, Erro: 0.3412, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.1046, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.2291, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.3036, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.1674, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.5822, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2809, Acurácia: 0.8667
# Época : 035, Treino: Erro: 0.2888, Acurácia: 85.7143%,
# 		Validação : Erro : 0.2809, Acurácia: 86.6667%, Tempo: 2.5127s
#
#
# Época: 36/50
# Treino - Lote número 000, Erro: 0.3029, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.2879, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.2341, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.3671, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.0184, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.1485, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.0693, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2975, Acurácia: 0.8667
# Época : 036, Treino: Erro: 0.2130, Acurácia: 89.5238%,
# 		Validação : Erro : 0.2975, Acurácia: 86.6667%, Tempo: 2.5315s
#
#
# Época: 37/50
# Treino - Lote número 000, Erro: 0.0528, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.1628, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.1442, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.1512, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.0938, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.1454, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.7262, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.3682, Acurácia: 0.8667
# Época : 037, Treino: Erro: 0.1765, Acurácia: 93.3333%,
# 		Validação : Erro : 0.3682, Acurácia: 86.6667%, Tempo: 2.6504s
#
#
# Época: 38/50
# Treino - Lote número 000, Erro: 0.2875, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.1957, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.1404, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.4670, Acurácia: 0.7500
# Treino - Lote número 004, Erro: 0.2073, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.2326, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.6357, Acurácia: 0.6667
# Validação - Lote número: 000, Erro: 0.3144, Acurácia: 0.8667
# Época : 038, Treino: Erro: 0.2877, Acurácia: 87.6190%,
# 		Validação : Erro : 0.3144, Acurácia: 86.6667%, Tempo: 2.6800s
#
#
# Época: 39/50
# Treino - Lote número 000, Erro: 0.0820, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.1700, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.2483, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.2024, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.2085, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.3318, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.1748, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2964, Acurácia: 0.8667
# Época : 039, Treino: Erro: 0.2044, Acurácia: 91.4286%,
# 		Validação : Erro : 0.2964, Acurácia: 86.6667%, Tempo: 2.5907s
#
#
# Época: 40/50
# Treino - Lote número 000, Erro: 0.0511, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.3663, Acurácia: 0.7500
# Treino - Lote número 002, Erro: 0.5224, Acurácia: 0.7500
# Treino - Lote número 003, Erro: 0.3522, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.0562, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.6005, Acurácia: 0.6875
# Treino - Lote número 006, Erro: 0.5436, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.4268, Acurácia: 0.7333
# Época : 040, Treino: Erro: 0.3435, Acurácia: 82.8571%,
# 		Validação : Erro : 0.4268, Acurácia: 73.3333%, Tempo: 2.5891s
#
#
# Época: 41/50
# Treino - Lote número 000, Erro: 0.1424, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.2707, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.1664, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.1820, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.1859, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.3048, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.1223, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3099, Acurácia: 0.9333
# Época : 041, Treino: Erro: 0.2013, Acurácia: 91.4286%,
# 		Validação : Erro : 0.3099, Acurácia: 93.3333%, Tempo: 2.5825s
#
#
# Época: 42/50
# Treino - Lote número 000, Erro: 0.2617, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.1199, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.1359, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.2300, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.2440, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.1729, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.0864, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.3948, Acurácia: 0.7333
# Época : 042, Treino: Erro: 0.1848, Acurácia: 91.4286%,
# 		Validação : Erro : 0.3948, Acurácia: 73.3333%, Tempo: 2.5549s
#
#
# Época: 43/50
# Treino - Lote número 000, Erro: 0.3278, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.2826, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.0731, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.1895, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.0538, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.6271, Acurácia: 0.6875
# Treino - Lote número 006, Erro: 0.1170, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2944, Acurácia: 0.9333
# Época : 043, Treino: Erro: 0.2468, Acurácia: 90.4762%,
# 		Validação : Erro : 0.2944, Acurácia: 93.3333%, Tempo: 2.5952s
#
#
# Época: 44/50
# Treino - Lote número 000, Erro: 0.1822, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.1844, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.1164, Acurácia: 0.9375
# Treino - Lote número 003, Erro: 0.0689, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.3682, Acurácia: 0.8125
# Treino - Lote número 005, Erro: 0.0763, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.3514, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2869, Acurácia: 0.9333
# Época : 044, Treino: Erro: 0.1820, Acurácia: 92.3810%,
# 		Validação : Erro : 0.2869, Acurácia: 93.3333%, Tempo: 2.6063s
#
#
# Época: 45/50
# Treino - Lote número 000, Erro: 0.2840, Acurácia: 0.8125
# Treino - Lote número 001, Erro: 0.1977, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.2840, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.4772, Acurácia: 0.8125
# Treino - Lote número 004, Erro: 0.1499, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.4934, Acurácia: 0.6875
# Treino - Lote número 006, Erro: 0.0522, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2811, Acurácia: 0.9333
# Época : 045, Treino: Erro: 0.2919, Acurácia: 85.7143%,
# 		Validação : Erro : 0.2811, Acurácia: 93.3333%, Tempo: 2.5828s
#
#
# Época: 46/50
# Treino - Lote número 000, Erro: 0.1829, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.2742, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.4569, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.2600, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.1082, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.2607, Acurácia: 0.9375
# Treino - Lote número 006, Erro: 0.1107, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.2709, Acurácia: 0.9333
# Época : 046, Treino: Erro: 0.2446, Acurácia: 90.4762%,
# 		Validação : Erro : 0.2709, Acurácia: 93.3333%, Tempo: 2.5545s
#
#
# Época: 47/50
# Treino - Lote número 000, Erro: 0.1909, Acurácia: 0.8750
# Treino - Lote número 001, Erro: 0.5979, Acurácia: 0.8125
# Treino - Lote número 002, Erro: 0.0552, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.1682, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.1184, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.1105, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.1491, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2521, Acurácia: 0.8667
# Época : 047, Treino: Erro: 0.2019, Acurácia: 91.4286%,
# 		Validação : Erro : 0.2521, Acurácia: 86.6667%, Tempo: 2.5988s
#
#
# Época: 48/50
# Treino - Lote número 000, Erro: 0.1221, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.1538, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.2801, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.4701, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.2898, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.1117, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.1414, Acurácia: 0.8889
# Validação - Lote número: 000, Erro: 0.2387, Acurácia: 0.8667
# Época : 048, Treino: Erro: 0.2297, Acurácia: 92.3810%,
# 		Validação : Erro : 0.2387, Acurácia: 86.6667%, Tempo: 2.6389s
#
#
# Época: 49/50
# Treino - Lote número 000, Erro: 0.2342, Acurácia: 0.9375
# Treino - Lote número 001, Erro: 0.2630, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.0312, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.2050, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.2387, Acurácia: 0.9375
# Treino - Lote número 005, Erro: 0.3647, Acurácia: 0.8125
# Treino - Lote número 006, Erro: 0.3846, Acurácia: 0.7778
# Validação - Lote número: 000, Erro: 0.2573, Acurácia: 0.9333
# Época : 049, Treino: Erro: 0.2367, Acurácia: 90.4762%,
# 		Validação : Erro : 0.2573, Acurácia: 93.3333%, Tempo: 2.6012s
#
#
# Época: 50/50
# Treino - Lote número 000, Erro: 0.0063, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.2426, Acurácia: 0.9375
# Treino - Lote número 002, Erro: 0.2809, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.2259, Acurácia: 0.9375
# Treino - Lote número 004, Erro: 0.0672, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.3450, Acurácia: 0.7500
# Treino - Lote número 006, Erro: 0.7404, Acurácia: 0.6667
# Validação - Lote número: 000, Erro: 0.2718, Acurácia: 0.8667
# Época : 050, Treino: Erro: 0.2414, Acurácia: 89.5238%,
# 		Validação : Erro : 0.2718, Acurácia: 86.6667%, Tempo: 2.6338s

# %%
# Mostra o erro de treino e validação a cada época treinada

historico = np.array(historico)

plt.plot(historico[:,0:2])
plt.legend(['Erro Treino', 'Erro Validação'])
plt.xlabel('Época')
plt.ylabel('Erro')
plt.ylim(0,1)
plt.savefig(dataset+'_curva_erro.png')
plt.show()

# %%
plt.plot(historico[:,2:4])
plt.legend(['Acurácia Treino', 'Acurácia Validação'])
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.ylim(0,1)
plt.savefig(dataset+'_curva_acuracia.png')
plt.show()

# %%
def predicao(modelo, arquivo_imagem_teste):
    '''
    Função para realizar a predição do status do AR
    Parâmetros
        :param modelo: modelo para testar
        :param arquivo_imagem_teste: caminho para imagem de teste
    '''
    
    transformacao = transformacoes_de_imagens['teste']

    imagem_teste = PIL.Image.open(arquivo_imagem_teste)
        
    tensor_imagem_teste = transformacao(imagem_teste)

    if torch.cuda.is_available():
        tensor_imagem_teste = tensor_imagem_teste.view(1, 3, image_size, image_size).cuda()
    else:
        tensor_imagem_teste = tensor_imagem_teste.view(1, 3, image_size, image_size)
    
    dict_predicoes = dict()
    
    # Não precisa atualizar os coeficientes do modelo
    with torch.no_grad():
        modelo.eval()
        # Modelo retorna as probabilidades em log (log softmax)
        saida = modelo(tensor_imagem_teste)
        
        # torch.exp para voltar a probabilidade de log para a probabilidade linear
        ps = torch.exp(saida)
        
        # topk retorna o os k maiores valores do tensor
        # o tensor de probabilidades vai trazer na 1a posição a classe com maior
        # probabilidade de predição
        topk, topclass = ps.topk(numero_de_classes, dim=1)
        for i in range(numero_de_classes):
            dict_predicoes[indice_para_classe[topclass.cpu().numpy()[0][i]]] = topk.cpu().numpy()[0][i]
    
    return dict_predicoes

# %%
test_folder = dataset + r'/teste'

def teste_acuracia(model, test_folder):
    classes = os.listdir(test_folder)
       
    correct_predictions = 0
    wrong_predictions = 0
    
    for cl in classes:
        cl1_files = os.listdir(os.path.join(test_folder, cl))
        
        for image in cl1_files:
            full_path_image = os.path.join(test_folder, cl, image)
            p = predicao(model, full_path_image)
            predicted_class = max(p, key=lambda key: p[key])
            
            if predicted_class == cl:
                correct_predictions += 1
            else:
                wrong_predictions += 1
    
    return correct_predictions / (correct_predictions + wrong_predictions)

# %%
acuracia_teste = teste_acuracia(modelo_treinado, test_folder)
acuracia_teste
# Out:
# 0.8666666666666667

# %%
for classe in range(3):
  classe_nome = indice_para_classe[classe]
  pasta = f'/content/drive/MyDrive/data/teste/{classe_nome}/'

  print(classe_nome)

  for item in range(5):
    imagem = os.path.join(pasta, os.listdir(pasta)[item])
    print(predicao(modelo_treinado, imagem))

  print("==================")
# Out:
# bayc
# {'bayc': 0.9969446, 'mayc': 0.0030542735, 'pap': 1.0119236e-06}
# {'bayc': 0.99799263, 'mayc': 0.0020064034, 'pap': 9.3481924e-07}
# {'bayc': 0.9945886, 'mayc': 0.0053883684, 'pap': 2.3009583e-05}
# {'bayc': 0.99421126, 'mayc': 0.0057857595, 'pap': 3.0102894e-06}
# {'bayc': 0.9133876, 'mayc': 0.08661183, 'pap': 6.948372e-07}
# ==================
# mayc
# {'mayc': 0.9630557, 'bayc': 0.036944203, 'pap': 7.419078e-08}
# {'bayc': 0.9840714, 'mayc': 0.015925867, 'pap': 2.8637678e-06}
# {'bayc': 0.75877994, 'mayc': 0.24121964, 'pap': 4.594652e-07}
# {'mayc': 0.657909, 'bayc': 0.34208626, 'pap': 4.818864e-06}
# {'mayc': 0.5135714, 'bayc': 0.4864234, 'pap': 5.182123e-06}
# ==================
# pap
# {'pap': 0.9998864, 'bayc': 0.00011280537, 'mayc': 8.222386e-07}
# {'pap': 0.9999988, 'bayc': 1.0140267e-06, 'mayc': 2.3575892e-07}
# {'pap': 0.99999905, 'bayc': 5.2633703e-07, 'mayc': 4.2539608e-07}
# {'pap': 0.99886984, 'bayc': 0.0011221694, 'mayc': 8.004497e-06}
# {'pap': 0.9999993, 'bayc': 5.417516e-07, 'mayc': 2.0101955e-07}
# ==================
